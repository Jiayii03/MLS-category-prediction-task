# %% [markdown]
# ## Model Inference
#
# This notebook serves as an example of the pipeline predicting the category of *new unseen* transaction (`inference.csv`). This dataset is sourced from the original `bank_transaction.csv` dataset, i.e. 257 instances with missing class labels. These instances were dropped during preprocessing hence **not seen** during training.
#
# These instances have no ground truth, let's see how the trained model is going to predict their categories :)
#
# Pipeline includes:
# 1. Data preprocessing (numerical + text)
# 2. Loading trained model weights
# 3. Model Inference

# %% [markdown]
# #### Load and Preprocess the New Inference Dataset

# %%
import pandas as pd
import numpy as np
import torch
import pickle
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# Import the text cleaning function from the util folder
from util.text_cleaning import clean_normalize_text

# Load the raw training dataset
df = pd.read_csv("../dataset/preprocessed_bank_transaction.csv")

# Load the new dataset for inference
inference_df = pd.read_csv("../dataset/inference.csv")

# Load the FastText model
from gensim.models import FastText
fasttext_model = FastText.load("../models/fasttext/fasttext_model.bin")

# Load the trained scaler
SCALER_PATH = "../models/scaler/scaler.pkl"
with open(SCALER_PATH, "rb") as f:
    scaler = pickle.load(f)

# %% [markdown]
# #### Defining Data Preprocessing Function

# %%
def preprocess_new_data(df, fasttext_model, scaler, structured_features):
    """Preprocess the new dataset without requiring a category column."""

    # Drop unnecessary columns (if exist)
    df = df.drop(columns=['client_id', 'bank_id', 'account_id', 'txn_id'], errors='ignore')

    # Convert txn_date to datetime format (if applicable)
    if 'txn_date' in df.columns:
        df['txn_date'] = pd.to_datetime(df['txn_date'], errors='coerce')

        # Extract time-based features
        df['day_of_week'] = df['txn_date'].dt.dayofweek  # Monday=0, Sunday=6
        df['day_of_month'] = df['txn_date'].dt.day  # 1-31
        df['hour'] = df['txn_date'].dt.hour  # Extract hour from transaction time (0-23)
        df['is_weekend'] = df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)  # 1=Weekend, 0=Weekday

        # Drop original txn_date column
        df = df.drop(columns=['txn_date'], errors='ignore')

    # Ensure transaction descriptions are cleaned first
    if 'description' in df.columns:
        df['processed_description'] = df['description'].fillna('').apply(clean_normalize_text)
    else:
        raise KeyError("Column 'description' is missing in the dataset!")

    # Generate FastText embeddings from cleaned transaction descriptions
    def get_embedding(text):
        words = str(text).split()  # Convert text to words
        word_vectors = [fasttext_model.wv[word] for word in words if word in fasttext_model.wv]
        if len(word_vectors) == 0:
            return np.zeros(100, dtype=np.float32)  # Ensure float32 dtype
        return np.mean(word_vectors, axis=0).astype(np.float32)  # Ensure float32 dtype

    df['fasttext_embedding'] = df['processed_description'].apply(get_embedding)
    fasttext_embeddings = np.vstack(df['fasttext_embedding'].values).astype(np.float32)  # Ensure float32

    # Drop raw text columns
    df = df.drop(columns=['description', 'processed_description', 'fasttext_embedding'], errors='ignore')

    # Apply the SAME scaler to inference data
    numerical_features = ['amount', 'day_of_week', 'day_of_month', 'hour']
    df[numerical_features] = scaler.transform(df[numerical_features])

    # Ensure correct data type
    df[structured_features] = df[structured_features].astype(np.float32)

    # Combine structured features and FastText embeddings into final feature matrix
    X_new = np.hstack((df[structured_features].values, fasttext_embeddings)).astype(np.float32)

    return X_new

# %%
# Extract structured numerical features (same as training)
structured_features = ['amount', 'is_interested_investment', 'is_interested_build_credit', 'is_interested_increase_income', 'is_interested_pay_off_debt', 'is_interested_manage_spending', 'is_interested_grow_savings', 'day_of_week', 'day_of_month', 'hour', 'is_weekend']

# Extract category column names from training dataset (ensuring consistent one-hot encoding)
category_columns = [col for col in df.columns if col.startswith("category_")]

# Preprocess new dataset
X_new = preprocess_new_data(inference_df, fasttext_model, scaler, structured_features)

# Convert to PyTorch tensor
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
X_new_tensor = torch.tensor(X_new, dtype=torch.float32).to(device)

# Print shape
print("New dataset shape after preprocessing:", X_new_tensor.shape)
# Out:
# New dataset shape after preprocessing: torch.Size([257, 111])

# %% [markdown]
# #### Initialise and Load the Trained Model
#
# For this inference, I'll be using the model trained with:
#
# - 50 epochs
# - 0.001 learning rate
# - BCELoss() as loss function
# - 82% average accuracy

# %%
import torch
import torch.nn as nn
from model import TransactionClassifier

# Load the trained model 
model_path = "../models/ann/ANN_50e_1e-3lr_bce_classifier.pth" 

# Initialize the model
model = TransactionClassifier(X_new_tensor.shape[1], len(category_columns))

model.load_state_dict(torch.load(model_path))
model.to(device)
model.eval()  # Set model to evaluation mode
# Out:
# TransactionClassifier(
#   (fc1): Linear(in_features=111, out_features=256, bias=True)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=128, out_features=33, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# #### Predicting Transaction Categories (Inference)
#
# Since these instances have no ground truth, it's therefore not feasible to compare or obtain its accuracy. I'll just print out the transaction description and the model prediction to roughly get an idea of how the model is performing.

# %%
# Perform inference
with torch.no_grad():
    outputs = model(X_new_tensor)  # Get model predictions
    predicted_categories = (outputs > 0.5).float()  # Convert logits to binary (threshold = 0.5)

# Convert one-hot predictions back to category labels
predicted_labels = []

for pred in predicted_categories.cpu().numpy():
    predicted_index = pred.argmax()  # Get index of the highest probability category
    predicted_labels.append(category_columns[predicted_index])  # Map index to category column

# Print the results
print("\n===== Model Predictions =====")

for i, (original, predicted) in enumerate(zip(inference_df['description'], predicted_labels)):
    print(f"Transaction {i+1}:")
    print(f"  Description: {original}")
    print(f"  Predicted Category: {predicted}")
    print("-" * 50)
# Out:
# ===== Model Predictions =====
# Transaction 1:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 2:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 3:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 4:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 5:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 6:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 7:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 8:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 9:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 10:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 11:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 12:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 13:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 14:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 15:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 16:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 17:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 18:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 19:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 20:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 21:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 22:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 23:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 24:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 25:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 26:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 27:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 28:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 29:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 30:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 31:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 32:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 33:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 34:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 35:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 36:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 37:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 38:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 39:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 40:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 41:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 42:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 43:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 44:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 45:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 46:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 47:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 48:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 49:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 50:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 51:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 52:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 53:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 54:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 55:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 56:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 57:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 58:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 59:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 60:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 61:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 62:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 63:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 64:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 65:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 66:
#   Description: Transfer from CB
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 67:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 68:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 69:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 70:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 71:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 72:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 73:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 74:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 75:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 76:
#   Description: Arby's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 77:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 78:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 79:
#   Description: Progressive
#   Predicted Category: category_Insurance
# --------------------------------------------------
# Transaction 80:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 81:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 82:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 83:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 84:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 85:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 86:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 87:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 88:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 89:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 90:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 91:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 92:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 93:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 94:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 95:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 96:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 97:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 98:
#   Description: INTERBANK TRANSFER TO 000:1036 - igit01 Maryse Hemant NY
#   Predicted Category: category_Internal Account Transfer
# --------------------------------------------------
# Transaction 99:
#   Description: PYMT TO RUMPKE WEB RECUR - 003 RUMPKE WEB RECURRING CINCINNATI OH
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 100:
#   Description: Dollar General
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 101:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 102:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 103:
#   Description: Store
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 104:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 105:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 106:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 107:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 108:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 109:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 110:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 111:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 112:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 113:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 114:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 115:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 116:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 117:
#   Description: KFC
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 118:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 119:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 120:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 121:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 122:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 123:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 124:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 125:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 126:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 127:
#   Description: Cash Withdrawal Fee
#   Predicted Category: category_Bank Fees
# --------------------------------------------------
# Transaction 128:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 129:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 130:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 131:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 132:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 133:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 134:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 135:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 136:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 137:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 138:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 139:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 140:
#   Description: ELECTRONIC IMAGE
#   Predicted Category: category_Uncategorized
# --------------------------------------------------
# Transaction 141:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 142:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 143:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 144:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 145:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 146:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 147:
#   Description: Walmart
#   Predicted Category: category_Supermarkets and Groceries
# --------------------------------------------------
# Transaction 148:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 149:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 150:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 151:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 152:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 153:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 154:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 155:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 156:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 157:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 158:
#   Description: Sunoco
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 159:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 160:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 161:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 162:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 163:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 164:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 165:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 166:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 167:
#   Description: Subway
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 168:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 169:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 170:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 171:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 172:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 173:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 174:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 175:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 176:
#   Description: Walmart
#   Predicted Category: category_Supermarkets and Groceries
# --------------------------------------------------
# Transaction 177:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 178:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 179:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 180:
#   Description: Sunoco
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 181:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 182:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 183:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 184:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 185:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 186:
#   Description: Wendy's
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 187:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 188:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 189:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 190:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 191:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 192:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 193:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 194:
#   Description: Subway
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 195:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 196:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 197:
#   Description: Dollar General
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 198:
#   Description: ENOVA LOC NETCRDIS 3168 062623
#   Predicted Category: category_Loans
# --------------------------------------------------
# Transaction 199:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 200:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 201:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 202:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 203:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 204:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 205:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 206:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 207:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 208:
#   Description: Dollar General
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 209:
#   Description: Walmart
#   Predicted Category: category_Supermarkets and Groceries
# --------------------------------------------------
# Transaction 210:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 211:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 212:
#   Description: ATM Withdrawal
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 213:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 214:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 215:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 216:
#   Description: Walmart
#   Predicted Category: category_Supermarkets and Groceries
# --------------------------------------------------
# Transaction 217:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 218:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 219:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 220:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 221:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 222:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 223:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 224:
#   Description: Transfer to CB
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 225:
#   Description: 5/3 JEANIE DEPOSIT 2306261 - 004463 5002 OLD TAYLR MILL Maryse Hemant KY ON 062623 FROM CARD#: 3168
#   Predicted Category: category_Transfer Deposit
# --------------------------------------------------
# Transaction 226:
#   Description: MERCHANT PAYMENT - 510001 UNITED DAIRY FA Maryse Hemant KY ON 062623 FROM CARD#: 3168
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 227:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 228:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 229:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 230:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 231:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 232:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 233:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 234:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 235:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 236:
#   Description: Dollar General
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 237:
#   Description: McDonald's
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 238:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 239:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 240:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 241:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 242:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 243:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 244:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 245:
#   Description: Maryse Hemant
#   Predicted Category: category_ATM
# --------------------------------------------------
# Transaction 246:
#   Description: Dollar General
#   Predicted Category: category_Shops
# --------------------------------------------------
# Transaction 247:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 248:
#   Description: Dunkin Donuts
#   Predicted Category: category_Restaurants
# --------------------------------------------------
# Transaction 249:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 250:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 251:
#   Description: Cash app*cash out      visa direct  caus
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 252:
#   Description: Cash App*Maryse Hemant
#   Predicted Category: category_Third Party
# --------------------------------------------------
# Transaction 253:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 254:
#   Description: Transfer to Chime Savings Account
#   Predicted Category: category_Transfer Debit
# --------------------------------------------------
# Transaction 255:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
# Transaction 256:
#   Description: Dandy Mini Mart
#   Predicted Category: category_Convenience Stores
# --------------------------------------------------
# Transaction 257:
#   Description: Transfer from Chime Savings Account
#   Predicted Category: category_Transfer Credit
# --------------------------------------------------
